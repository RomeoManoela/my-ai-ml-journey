# %%
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as sk
# %matplotlib inline

# %%
df = pd.read_csv('hours_score.csv')
df.head()
# Out:
#    Hours  Score
# 0    2.0     50
# 1    3.0     55
# 2    4.5     70
# 3    5.0     71
# 4    6.0     78

# %%
X = df[['Hours']]
Y = df[['Score']]

# %%
X_train, X_test, Y_train, Y_test = sk.model_selection.train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
sc = sk.preprocessing.StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
model = sk.linear_model.LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
plt.scatter(X_test, Y_test, color='black')
plt.plot(X_test, model.predict(X_test), color='red')

# %%
print("R2", sk.metrics.r2_score(Y_test, y_test_pred))
print("MSE", sk.metrics.mean_squared_error(Y_test, model.predict(X_test)))
# Out:
# R2 0.9867567048835848
# MSE 4.500145254419634

# %%
pd_to_predict = pd.DataFrame([5, 10, 1, 3, 2], columns=['Hours'])
pd_to_predict = sc.transform(pd_to_predict)
predicted = model.predict(pd_to_predict)
print(predicted)
# Out:
# [[ 69.5596666 ]
#  [100.14428268]
#  [ 45.09197373]
#  [ 57.32582016]
#  [ 51.20889695]]
